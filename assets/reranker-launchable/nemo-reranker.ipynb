# %% [markdown]
# ## DRAFT - Reranker launchable
#
# This notebook by Ishan follows https://docs.nvidia.com/nim/nemo-retriever/text-reranking/latest/playbook.html#option-2-text-embedding-nim. We specifically deploy the reranker nim in this instance so that the notebook can use it

# %%
# %%bash
#
# wget https://raw.githubusercontent.com/brevdev/notebooks/main/assets/reranker-launchable/requirements.txt -O requirements.txt
# pip install -r requirements.txt
# Out:
# --2024-08-05 22:08:28--  https://raw.githubusercontent.com/brevdev/notebooks/main/assets/reranker-launchable/requirements.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 204 [text/plain]
# Saving to: ‘requirements.txt’
#
#      0K                                                       100% 23.6M=0s
#
# 2024-08-05 22:08:28 (23.6 MB/s) - ‘requirements.txt’ saved [204/204]
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 8.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.5/807.5 kB 6.8 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.1 MB/s eta 0:00:0000:0100:01
# ...

# %%
# %%bash
#
# wget https://raw.githubusercontent.com/brevdev/notebooks/main/assets/reranker-launchable/install-docker.sh -O install-docker
# chmod +x install-docker
